# %% [markdown]
# # Import

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.lines as mlines
import numpy as np
import os
from datetime import datetime
from matplotlib import patheffects
import matplotlib.ticker as ticker
from matplotlib.lines import Line2D
import matplotlib.dates as mdates
import matplotlib.ticker as mticker
import seaborn as sns
import nbsphinx

# %%
TEMPLATE_PATH = os.path.abspath(os.path.join(os.getcwd(), "..", "..", "_templates"))

# %%
# Daten einlesen
wahlen_df = pd.read_pickle(os.path.join(TEMPLATE_PATH, "wahlen.pickle"))
wordcount_df = pd.read_pickle(os.path.join(TEMPLATE_PATH, "wordcount.pickle"))

# %%
# Liste der Parteifarben
parteifarben = {'cdu': 'black', 'spd': 'red', 'grüne': 'green','grünen': 'green',
                'fdp': '#DAA520', 'linke': 'purple', 'afd': 'blue'}

# %% [markdown]
# ## Analyse

# %%
# Verteilung der Artikel pro Zeitung
paper_counts = wordcount_df["paper"].value_counts()

# Barplot erstellen
plt.figure(figsize=(10, 6))
paper_counts.plot(kind="bar", color="skyblue", edgecolor="black")
plt.title("Anzahl der Artikel pro Zeitung", fontsize=16)
plt.xlabel("Zeitung", fontsize=14)
plt.ylabel("Anzahl der Artikel", fontsize=14)
plt.xticks(rotation=45)
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Gruppieren nach Zeitung und Partei
party_paper_distribution = wordcount_df.groupby(["paper", "word"])["count"].sum().unstack(fill_value=0)

# Gestapelter Barplot
party_paper_distribution.plot(kind="bar", stacked=True, figsize=(12, 7), colormap="tab20")
plt.title("Anteil der Parteien pro Zeitung", fontsize=16)
plt.xlabel("Zeitung", fontsize=14)
plt.ylabel("Anzahl der Nennungen", fontsize=14)
plt.xticks(rotation=45)
plt.legend(title="Partei", fontsize=10)
plt.tight_layout()
plt.show()

# %%
# Gruppieren nach Zeitung und Partei
heatmap_data = wordcount_df.groupby(["paper", "word"])["count"].sum().unstack(fill_value=0)

# Heatmap erstellen mit der Farbpalette "YlOrBr" (Yellow-Orange-Brown)
plt.figure(figsize=(12, 7))
sns.heatmap(heatmap_data, cmap="YlOrBr", annot=True,fmt="d", cbar=False)

plt.xlabel("", fontsize=14)
plt.ylabel("", fontsize=14)
plt.tight_layout()
plt.show()

# %%
# Gesamtsumme der Nennungen wordcount_dfr Parteien
total_words = wordcount_df["count"].sum()

# Prozentanteil für jede Partei berechnen
party_percentages = (
    wordcount_df.groupby("word")["count"].sum() / total_words * 100
).sort_values(ascending=False)

# Ergebnisse anzeigen
for party, percentage in party_percentages.items():
    print(f"Prozentanteil von '{party}': {percentage:.2f}%")
# Out:
# Prozentanteil von 'afd': 20.44%
# Prozentanteil von 'spd': 18.63%
# Prozentanteil von 'cdu': 18.26%
# Prozentanteil von 'grünen': 15.08%
# Prozentanteil von 'fdp': 12.57%
# Prozentanteil von 'linke': 12.34%
# Prozentanteil von 'bsw': 2.68%

# %%
# Gruppieren nach Zeitung und Partei, dann aufsummieren
portal_party_counts = wordcount_df.groupby(["paper", "word"])["count"].sum()

# Für jede Partei das Portal mit den höchsten Nennungen finden
top_portal_per_party = portal_party_counts.groupby("word").idxmax()

# Ergebnisse extrahieren
for party, (paper, _) in top_portal_per_party.items():
    print(f"Die meisten Berichte über '{party}' kommen von '{paper}' mit {portal_party_counts[paper, party]} Nennungen.")
# Out:
# Die meisten Berichte über 'afd' kommen von 'welt' mit 4099 Nennungen.
# Die meisten Berichte über 'bsw' kommen von 'dlf' mit 584 Nennungen.
# Die meisten Berichte über 'cdu' kommen von 'welt' mit 4279 Nennungen.
# Die meisten Berichte über 'fdp' kommen von 'welt' mit 2950 Nennungen.
# Die meisten Berichte über 'grünen' kommen von 'welt' mit 4437 Nennungen.
# Die meisten Berichte über 'linke' kommen von 'taz' mit 3214 Nennungen.
# Die meisten Berichte über 'spd' kommen von 'welt' mit 4698 Nennungen.

# %%
# Gesamtnennungen pro Zeitung
total_counts_per_paper = wordcount_df.groupby("paper")["count"].sum()

# Gruppieren nach Zeitung und Partei, dann Summen berechnen
portal_party_counts = wordcount_df.groupby(["paper", "word"])["count"].sum()

# Prozentualen Anteil jeder Partei pro Zeitung berechnen
portal_party_percentages = portal_party_counts.div(total_counts_per_paper, level=0) * 100

# Ergebnisse anzeigen
for (paper, party), percentage in portal_party_percentages.items():
    print(f"{paper} berichtet zu {percentage:.2f}% über '{party}'.")
# Out:
# abendblatt berichtet zu 17.72% über 'afd'.
# abendblatt berichtet zu 2.38% über 'bsw'.
# abendblatt berichtet zu 23.02% über 'cdu'.
# abendblatt berichtet zu 11.19% über 'fdp'.
# abendblatt berichtet zu 13.11% über 'grünen'.
# abendblatt berichtet zu 10.70% über 'linke'.
# abendblatt berichtet zu 21.89% über 'spd'.
# berliner berichtet zu 22.26% über 'afd'.
# berliner berichtet zu 5.77% über 'bsw'.
# berliner berichtet zu 16.59% über 'cdu'.
# berliner berichtet zu 7.21% über 'fdp'.
# berliner berichtet zu 12.80% über 'grünen'.
# berliner berichtet zu 17.54% über 'linke'.
# berliner berichtet zu 17.82% über 'spd'.
# dlf berichtet zu 22.14% über 'afd'.
# dlf berichtet zu 3.41% über 'bsw'.
# dlf berichtet zu 21.54% über 'cdu'.
# dlf berichtet zu 13.63% über 'fdp'.
# dlf berichtet zu 10.18% über 'grünen'.
# dlf berichtet zu 7.15% über 'linke'.
# dlf berichtet zu 21.95% über 'spd'.
# esslinger berichtet zu 16.29% über 'afd'.
# esslinger berichtet zu 1.01% über 'bsw'.
# esslinger berichtet zu 23.30% über 'cdu'.
# esslinger berichtet zu 13.33% über 'fdp'.
# esslinger berichtet zu 18.09% über 'grünen'.
# esslinger berichtet zu 7.88% über 'linke'.
# esslinger berichtet zu 20.09% über 'spd'.
# faz berichtet zu 15.22% über 'afd'.
# faz berichtet zu 2.14% über 'bsw'.
# faz berichtet zu 17.58% über 'cdu'.
# faz berichtet zu 11.67% über 'fdp'.
# faz berichtet zu 17.68% über 'grünen'.
# faz berichtet zu 18.32% über 'linke'.
# faz berichtet zu 17.39% über 'spd'.
# heise berichtet zu 9.95% über 'afd'.
# heise berichtet zu 2.77% über 'bsw'.
# heise berichtet zu 18.56% über 'cdu'.
# heise berichtet zu 12.39% über 'fdp'.
# heise berichtet zu 15.96% über 'grünen'.
# heise berichtet zu 30.48% über 'linke'.
# heise berichtet zu 9.89% über 'spd'.
# ntv berichtet zu 19.68% über 'afd'.
# ntv berichtet zu 2.84% über 'bsw'.
# ntv berichtet zu 21.16% über 'cdu'.
# ntv berichtet zu 15.52% über 'fdp'.
# ntv berichtet zu 12.54% über 'grünen'.
# ntv berichtet zu 8.16% über 'linke'.
# ntv berichtet zu 20.10% über 'spd'.
# pioneer berichtet zu 3.98% über 'afd'.
# pioneer berichtet zu 0.35% über 'bsw'.
# pioneer berichtet zu 12.89% über 'cdu'.
# pioneer berichtet zu 7.66% über 'fdp'.
# pioneer berichtet zu 12.09% über 'grünen'.
# pioneer berichtet zu 54.65% über 'linke'.
# pioneer berichtet zu 8.37% über 'spd'.
# spiegel berichtet zu 21.87% über 'afd'.
# spiegel berichtet zu 1.53% über 'bsw'.
# spiegel berichtet zu 16.94% über 'cdu'.
# spiegel berichtet zu 14.15% über 'fdp'.
# spiegel berichtet zu 16.49% über 'grünen'.
# spiegel berichtet zu 11.06% über 'linke'.
# spiegel berichtet zu 17.95% über 'spd'.
# stern berichtet zu 25.49% über 'afd'.
# stern berichtet zu 3.21% über 'bsw'.
# stern berichtet zu 19.04% über 'cdu'.
# stern berichtet zu 11.76% über 'fdp'.
# stern berichtet zu 11.96% über 'grünen'.
# stern berichtet zu 8.62% über 'linke'.
# stern berichtet zu 19.91% über 'spd'.
# suedwest berichtet zu 21.96% über 'afd'.
# suedwest berichtet zu 2.05% über 'bsw'.
# suedwest berichtet zu 22.16% über 'cdu'.
# suedwest berichtet zu 12.76% über 'fdp'.
# suedwest berichtet zu 17.87% über 'grünen'.
# suedwest berichtet zu 5.53% über 'linke'.
# suedwest berichtet zu 17.67% über 'spd'.
# sz berichtet zu 23.75% über 'afd'.
# sz berichtet zu 1.95% über 'bsw'.
# sz berichtet zu 14.48% über 'cdu'.
# sz berichtet zu 15.99% über 'fdp'.
# sz berichtet zu 18.87% über 'grünen'.
# sz berichtet zu 7.79% über 'linke'.
# sz berichtet zu 17.16% über 'spd'.
# tagesschau berichtet zu 27.15% über 'afd'.
# tagesschau berichtet zu 2.79% über 'bsw'.
# tagesschau berichtet zu 17.96% über 'cdu'.
# tagesschau berichtet zu 12.71% über 'fdp'.
# tagesschau berichtet zu 12.22% über 'grünen'.
# tagesschau berichtet zu 7.78% über 'linke'.
# tagesschau berichtet zu 19.40% über 'spd'.
# tagesspiegel berichtet zu 19.61% über 'afd'.
# tagesspiegel berichtet zu 2.34% über 'bsw'.
# tagesspiegel berichtet zu 18.47% über 'cdu'.
# tagesspiegel berichtet zu 12.03% über 'fdp'.
# tagesspiegel berichtet zu 15.48% über 'grünen'.
# tagesspiegel berichtet zu 9.73% über 'linke'.
# tagesspiegel berichtet zu 22.34% über 'spd'.
# taz berichtet zu 22.89% über 'afd'.
# taz berichtet zu 2.51% über 'bsw'.
# taz berichtet zu 15.09% über 'cdu'.
# taz berichtet zu 8.80% über 'fdp'.
# taz berichtet zu 15.10% über 'grünen'.
# taz berichtet zu 20.08% über 'linke'.
# taz berichtet zu 15.53% über 'spd'.
# uebermedien berichtet zu 46.50% über 'afd'.
# uebermedien berichtet zu 1.37% über 'bsw'.
# uebermedien berichtet zu 18.19% über 'cdu'.
# uebermedien berichtet zu 8.78% über 'fdp'.
# uebermedien berichtet zu 6.67% über 'grünen'.
# uebermedien berichtet zu 8.11% über 'linke'.
# uebermedien berichtet zu 10.37% über 'spd'.
# welt berichtet zu 17.51% über 'afd'.
# welt berichtet zu 2.23% über 'bsw'.
# welt berichtet zu 18.28% über 'cdu'.
# welt berichtet zu 12.60% über 'fdp'.
# welt berichtet zu 18.96% über 'grünen'.
# welt berichtet zu 10.34% über 'linke'.
# welt berichtet zu 20.07% über 'spd'.
# wiwo berichtet zu 11.19% über 'afd'.
# wiwo berichtet zu 6.99% über 'bsw'.
# wiwo berichtet zu 16.42% über 'cdu'.
# wiwo berichtet zu 18.56% über 'fdp'.
# wiwo berichtet zu 22.19% über 'grünen'.
# wiwo berichtet zu 6.57% über 'linke'.
# wiwo berichtet zu 18.08% über 'spd'.
# zeit berichtet zu 25.20% über 'afd'.
# zeit berichtet zu 2.22% über 'bsw'.
# zeit berichtet zu 17.58% über 'cdu'.
# zeit berichtet zu 13.85% über 'fdp'.
# zeit berichtet zu 13.84% über 'grünen'.
# zeit berichtet zu 10.92% über 'linke'.
# zeit berichtet zu 16.39% über 'spd'.

# %%
# In ein DataFrame umwandeln
portal_party_percentages_df = portal_party_percentages.unstack().fillna(0)

# Tabellarische Anzeige
print(portal_party_percentages_df)
# Out:
# word                afd       bsw        cdu        fdp     grünen      linke  \
# paper
# abendblatt    17.715280  2.377501  23.021166  11.191650  13.105248  10.698753
# berliner      22.263330  5.767138  16.594124   7.214363  12.796518  17.540805
# dlf           22.141773  3.410020  21.540348  13.628401  10.177508   7.152867
# esslinger     16.293368  1.010101  23.298199  13.328942  18.093983   7.883180
# faz           15.222386  2.141802  17.577548  11.669129  17.676022  18.324307
# heise          9.946809  2.765957  18.563830  12.393617  15.957447  30.478723
# ntv           19.676422  2.837259  21.157507  15.524625  12.538663   8.160837
# pioneer        3.983031  0.353523  12.891822   7.659675  12.090502  54.654725
# spiegel       21.874628  1.534436  16.938266  14.154871  16.486261  11.062210
# stern         25.492817  3.207484  19.044437  11.760775  11.961243   8.620114
# suedwest      21.964424  2.049497  22.157773  12.761021  17.865429   5.529776
# sz            23.745601  1.954907  14.479343  15.991138  18.871367   7.793562
# tagesschau    27.145188  2.789560  17.960848  12.707993  12.218597   7.781403
# tagesspiegel  19.609508  2.341955  18.465994  12.029362  15.484870   9.732348
# taz           22.886598  2.511715  15.089035   8.803499  15.095283  20.081225
# uebermedien   46.504947  1.372486  18.193425   8.777530   6.670922   8.107245
# welt          17.512604  2.234470  18.281637  12.603606  18.956678  10.339229
# wiwo          11.189469  6.989500  16.423758  18.555085  22.190879   6.566369
# zeit          25.201834  2.221792  17.580572  13.847446  13.840987  10.915197
#
# word                spd
# paper
# abendblatt    21.890403
# berliner      17.823721
# dlf           21.949083
# esslinger     20.092227
# faz           17.388807
# heise          9.893617
# ntv           20.104687
# pioneer        8.366722
# spiegel       17.949328
# stern         19.913131
# suedwest      17.672080
# sz            17.164082
# tagesschau    19.396411
# tagesspiegel  22.335963
# taz           15.532646
# uebermedien   10.373444
# welt          20.071776
# wiwo          18.084940
# zeit          16.392172

# %%
# Series in ein DataFrame umwandeln
portal_party_percentages_df = portal_party_percentages.unstack()

# Durchschnittliche Berichterstattung pro Partei berechnen
average_party_coverage = portal_party_percentages_df.mean().sort_values(ascending=False)

# Ergebnisse anzeigen
print("Durchschnittliche Berichterstattung pro Partei:")
print(average_party_coverage)
# Out:
# Durchschnittliche Berichterstattung pro Partei:
# word
# afd       20.545790
# cdu       18.382086
# spd       17.494486
# grünen    14.846232
# linke     13.759099
# fdp       12.347512
# bsw        2.624795
# dtype: float64

# %% [markdown]
# Daten im Jahr 2024

# %%
# Filtere die Daten für das Jahr 2024
data_2024 = wordcount_df[wordcount_df["date"].dt.year == 2024]

# Gesamtnennungen pro Zeitung im Jahr 2024
total_counts_per_paper_2024 = data_2024.groupby("paper")["count"].sum()

# Gruppieren nach Zeitung und Partei im Jahr 2024
portal_party_counts_2024 = data_2024.groupby(["paper", "word"])["count"].sum()

# Prozentualen Anteil jeder Partei pro Zeitung im Jahr 2024 berechnen
portal_party_percentages_2024 = portal_party_counts_2024.div(total_counts_per_paper_2024, level=0) * 100

# Series in ein DataFrame umwandeln
portal_party_percentages_2024_df = portal_party_percentages_2024.unstack()

# Durchschnittliche Berichterstattung pro Partei im Jahr 2024 berechnen
average_party_coverage_2024 = portal_party_percentages_2024_df.mean().sort_values(ascending=False)

# Ergebnisse anzeigen
print("Durchschnittliche Berichterstattung pro Partei im Jahr 2024:")
print(average_party_coverage_2024)
# Out:
# Durchschnittliche Berichterstattung pro Partei im Jahr 2024:
# word
# afd       32.099678
# spd       15.356324
# cdu       14.360711
# linke     11.176606
# fdp       10.702306
# grünen    10.363510
# bsw        5.940865
# dtype: float64

# %%
print(portal_party_percentages_2024_df)
# Out:
# word                afd        bsw        cdu        fdp     grünen  \
# paper
# abendblatt    29.105572   5.351906  15.762463  10.850440   9.677419
# berliner      35.879874  13.883035  12.565859   4.952582   9.457323
# dlf           33.758049   7.768187  15.919989  12.070147   7.562680
# esslinger     28.036606   2.246256  19.134775  10.565724  15.058236
# faz           23.998910   5.802234  14.873332  10.950695  13.538545
# heise         17.341040   4.624277  25.626204   9.248555   7.707129
# ntv           32.196237   6.840162  14.612274  13.996835   8.475470
# pioneer       14.421769   2.040816   7.482993  10.612245   5.714286
# spiegel       34.643644   4.518736  12.674504  10.947832  11.388685
# stern         36.106195   7.787611  14.424779   8.230088   7.876106
# suedwest      33.259669   5.524862  14.806630  11.270718  15.801105
# sz            46.474820   4.556355   9.640288   7.961631   9.928058
# tagesschau    36.082972   8.152436  13.072841  12.156295   8.393632
# tagesspiegel  25.914428   6.208665  16.142529  11.553516  11.917938
# taz           33.394194   7.084170  12.360781   5.641775  10.973160
# uebermedien   56.615662   3.870387  10.351035  10.171017   6.030603
# welt          29.902540   6.098641  15.829888  10.440047  13.777318
# wiwo          26.579112   5.753596  12.820513  19.637273  13.258286
# zeit          36.182598   4.764093  14.751838  12.086397  10.370711
#
# word              linke        spd
# paper
# abendblatt    10.923754  18.328446
# berliner      10.353003  12.908325
# dlf            6.274832  16.646116
# esslinger      6.239601  18.718802
# faz           15.826750  15.009534
# heise         30.250482   5.202312
# ntv            5.925796  17.953227
# pioneer       46.530612  13.197279
# spiegel        8.523145  17.303453
# stern          4.778761  20.796460
# suedwest       3.425414  15.911602
# sz             6.474820  14.964029
# tagesschau     6.078148  16.063676
# tagesspiegel   6.627075  21.635848
# taz           16.925324  13.620595
# uebermedien    7.470747   5.490549
# welt           7.471943  16.479622
# wiwo           4.565353  17.385866
# zeit           7.689951  14.154412

# %% [markdown]
# Parteien bis 2024

# %%
# Filtere die Daten bis einschließlich 2024
data_until_2024 = wordcount_df[wordcount_df["date"].dt.year <= 2024]

# Gesamtnennungen pro Zeitung bis 2024
total_counts_per_paper_until_2024 = data_until_2024.groupby("paper")["count"].sum()

# Gruppieren nach Zeitung und Partei bis 2024
portal_party_counts_until_2024 = data_until_2024.groupby(["paper", "word"])["count"].sum()

# Prozentualen Anteil jeder Partei pro Zeitung bis 2024 berechnen
portal_party_percentages_until_2024 = portal_party_counts_until_2024.div(total_counts_per_paper_until_2024, level=0) * 100

# Series in ein DataFrame umwandeln
portal_party_percentages_until_2024_df = portal_party_percentages_until_2024.unstack()

# Durchschnittliche Berichterstattung pro Partei bis 2024 berechnen
average_party_coverage_until_2024 = portal_party_percentages_until_2024_df.mean().sort_values(ascending=False)

# Ergebnisse anzeigen
print("Durchschnittliche Berichterstattung pro Partei bis einschließlich 2024:")
print(average_party_coverage_until_2024)
# Out:
# Durchschnittliche Berichterstattung pro Partei bis einschließlich 2024:
# word
# afd       20.545790
# cdu       18.382086
# spd       17.494486
# grünen    14.846232
# linke     13.759099
# fdp       12.347512
# bsw        2.624795
# dtype: float64

# %%
print(portal_party_percentages_until_2024_df)
# Out:
# word                afd       bsw        cdu        fdp     grünen      linke  \
# paper
# abendblatt    17.715280  2.377501  23.021166  11.191650  13.105248  10.698753
# berliner      22.263330  5.767138  16.594124   7.214363  12.796518  17.540805
# dlf           22.141773  3.410020  21.540348  13.628401  10.177508   7.152867
# esslinger     16.293368  1.010101  23.298199  13.328942  18.093983   7.883180
# faz           15.222386  2.141802  17.577548  11.669129  17.676022  18.324307
# heise          9.946809  2.765957  18.563830  12.393617  15.957447  30.478723
# ntv           19.676422  2.837259  21.157507  15.524625  12.538663   8.160837
# pioneer        3.983031  0.353523  12.891822   7.659675  12.090502  54.654725
# spiegel       21.874628  1.534436  16.938266  14.154871  16.486261  11.062210
# stern         25.492817  3.207484  19.044437  11.760775  11.961243   8.620114
# suedwest      21.964424  2.049497  22.157773  12.761021  17.865429   5.529776
# sz            23.745601  1.954907  14.479343  15.991138  18.871367   7.793562
# tagesschau    27.145188  2.789560  17.960848  12.707993  12.218597   7.781403
# tagesspiegel  19.609508  2.341955  18.465994  12.029362  15.484870   9.732348
# taz           22.886598  2.511715  15.089035   8.803499  15.095283  20.081225
# uebermedien   46.504947  1.372486  18.193425   8.777530   6.670922   8.107245
# welt          17.512604  2.234470  18.281637  12.603606  18.956678  10.339229
# wiwo          11.189469  6.989500  16.423758  18.555085  22.190879   6.566369
# zeit          25.201834  2.221792  17.580572  13.847446  13.840987  10.915197
#
# word                spd
# paper
# abendblatt    21.890403
# berliner      17.823721
# dlf           21.949083
# esslinger     20.092227
# faz           17.388807
# heise          9.893617
# ntv           20.104687
# pioneer        8.366722
# spiegel       17.949328
# stern         19.913131
# suedwest      17.672080
# sz            17.164082
# tagesschau    19.396411
# tagesspiegel  22.335963
# taz           15.532646
# uebermedien   10.373444
# welt          20.071776
# wiwo          18.084940
# zeit          16.392172

# %% [markdown]
# Wie oft wurden die Parteien gennant

# %%
data_before_2024 = wordcount_df[wordcount_df["date"].dt.year < 2024]
data_2024 = wordcount_df[wordcount_df["date"].dt.year == 2024]

wordcount_before_2024 = data_before_2024.groupby("word")["count"].sum()
wordcount_2024 = data_2024.groupby("word")["count"].sum()

total_before_2024 = wordcount_before_2024.sum()
total_2024 = wordcount_2024.sum()


percentage_before_2024 = (wordcount_before_2024 / total_before_2024 * 100).sort_values(ascending=False)
percentage_2024 = (wordcount_2024 / total_2024 * 100).sort_values(ascending=False)

percent_change = percentage_2024 - percentage_before_2024

print("Prozentuale Verteilung der Nennungen vor 2024:")
print(percentage_before_2024)

print("\nProzentuale Verteilung der Nennungen im Jahr 2024:")
print(percentage_2024)

print("\nProzentuale Veränderung der Nennungen von vor 2024 zu 2024:")
print(percent_change)
# Out:
# Prozentuale Verteilung der Nennungen vor 2024:
# word
# cdu       20.224287
# spd       19.861347
# grünen    17.406066
# afd       14.301006
# linke     14.017511
# fdp       13.515751
# bsw        0.674031
# Name: count, dtype: float64
#
# Prozentuale Verteilung der Nennungen im Jahr 2024:
# word
# afd       32.257909
# spd       16.266671
# cdu       14.481992
# fdp       10.738677
# grünen    10.600155
# linke      9.103795
# bsw        6.550802
# Name: count, dtype: float64
#
# Prozentuale Veränderung der Nennungen von vor 2024 zu 2024:
# word
# afd       17.956903
# bsw        5.876771
# cdu       -5.742295
# fdp       -2.777074
# grünen    -6.805912
# linke     -4.913717
# spd       -3.594676
# Name: count, dtype: float64

# %%
# Daten vorbereiten
data_before_2024 = wordcount_df[wordcount_df["date"].dt.year < 2024]
data_2024 = wordcount_df[wordcount_df["date"].dt.year == 2024]

# Gruppierung nach "word" und Aufsummierung der Werte
wordcount_before_2024 = data_before_2024.groupby("word")["count"].sum()
wordcount_2024 = data_2024.groupby("word")["count"].sum()

# Gesamtsummen für Prozentuale Verteilung
total_before_2024 = wordcount_before_2024.sum()
total_2024 = wordcount_2024.sum()

# Prozentuale Verteilung berechnen
percentage_before_2024 = (wordcount_before_2024 / total_before_2024 * 100).sort_index()
percentage_2024 = (wordcount_2024 / total_2024 * 100).sort_index()

# Prozentuale Veränderung zwischen 2024 und vorher
percent_change = percentage_2024 - percentage_before_2024

# Sicherstellen, dass die Indizes korrekt ausgerichtet sind
percentage_before_2024 = percentage_before_2024.reindex(percentage_2024.index)

# Balkendiagramme erstellen
fig, ax = plt.subplots(1, 2, figsize=(14, 6), gridspec_kw={'width_ratios': [2, 1]})

# Subplot 1: Prozentuale Verteilung vor 2024 vs. 2024
width = 0.4
x = range(len(percentage_before_2024.index))
ax[0].bar(x, percentage_before_2024.values, width=width, label="Vor 2024", align='center', alpha=0.7)
ax[0].bar([p + width for p in x], percentage_2024.values, width=width, label="2024", align='center', alpha=0.7)
ax[0].set_xticks([p + width / 2 for p in x])
ax[0].set_xticklabels(percentage_before_2024.index, rotation=45)
ax[0].set_title("Prozentuale Verteilung vor 2024 vs. 2024")
ax[0].set_ylabel("Prozentuale Verteilung (%)")
ax[0].legend()
ax[0].grid(axis="y", linestyle="--", alpha=0.7)

# Subplot 2: Prozentuale Veränderung von 2023 zu 2024
colors = ["green" if x > 0 else "red" for x in percent_change.values]
ax[1].barh(percent_change.index, percent_change.values, color=colors, alpha=0.8)
ax[1].set_xlabel("Veränderung (%)")
ax[1].axvline(0, color="black", linestyle="--", linewidth=0.7)
ax[1].grid(axis="x", linestyle="--", alpha=0.7)

# Layout optimieren und Plot anzeigen
plt.tight_layout()
plt.show()
